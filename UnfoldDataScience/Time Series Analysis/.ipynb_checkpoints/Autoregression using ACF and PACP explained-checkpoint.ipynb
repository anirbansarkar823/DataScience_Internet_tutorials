# %%
import os
os.chdir("give_correct_path")

# %%
from IPython.display import Image
Image(filename='PACF.png')

# %% [markdown]
# ## Aurocorrelation
# ### Values of a time series may be correlated with previous values in the same series in many different ways. Such correlation over time, often called autocorrelation, represents the temporal dynamics of a time series.

# %% [markdown]
# # Time series lag example
# # Original time series = {21,22,21,20,19}
# # Lagged time series by 1 lag = {22,21,20,19}
#
# # Lag 1 correlation will be correlation between {21,22,21,20} and {22,21,20,19}

# %% [markdown]
# # What is Autoregression? -
# # A statistical model is autoregressive if it predicts future values based on past values.

# %% [markdown]
# # ACF Definition - A function which gives us values of auto-correlation of any series with its lagged values.

# %% [markdown]
# # PACF Definition - An indirect function to find Auto correlation after removing the relationship explained by previous lags

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline 

import matplotlib
matplotlib.rc('xtick', labelsize=30) 
matplotlib.rc('ytick', labelsize=30) 

import seaborn as sns
sns.set(style="darkgrid", color_codes=True)
from statsmodels.tsa.stattools import acf, pacf

# %%
axisline = np.linspace(0, 10, 500) # generating 500 numbers between 0 and 10 (inclusive)


#normal distributed values
normalnumbers = np.random.normal(0,5,500) # np.random.normal(mean, sd, size_of_output)

# %%
# plotting only the normally distributed data
plt.figure(figsize=(16,7))
plt.plot(axisline, normalnumbers)

# %%
#exponential series to get the trend
ExponentialData = np.exp(axisline**0.5) # Calculates the exponential of all elements in the input array


# plotting just the exponentially distributed data
plt.figure(figsize=(16,7))
plt.plot(axisline,ExponentialData)

# %%
#adding normally distributed series in exponential series
y = normalnumbers + ExponentialData #element wise array addition

#plot
plt.figure(figsize=(16,7))
plt.plot(axisline,y) #line chart

# %%
#calling auto correlation function
ACF_lag= acf(y, nlags=200) # the lagging value, after which calculation will start is 200; first 200 values would be skipped



#Plot ACF:
plt.figure(figsize=(16, 7))
plt.plot(ACF_lag,marker='+')

# The axhline() function in pyplot module of matplotlib library is used to add a horizontal line across the axis.
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(y)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(y)),linestyle='--',color='gray')
plt.title('Autocorrelation')
plt.xlabel('#lags')
plt.ylabel('correlation')
plt.tight_layout()
# Out:
# W:\Softwares\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py:662: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
#calling partial correlation function
PACF_lag = pacf(y, nlags=30, method='ols')

#Plot PACF:
plt.figure(figsize=(16, 7))
plt.plot(PACF_lag,marker='+')

# The axhline() function in pyplot module of matplotlib library is used to add a horizontal line across the axis.
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(y)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(y)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation')
plt.xlabel('#lags')
plt.ylabel('correlation')
plt.xticks(list(range(34))) # for setting values in x-axis
plt.tight_layout()

# %%
#AR(7) ---- as at 7, the pacf touches the 0 mark
